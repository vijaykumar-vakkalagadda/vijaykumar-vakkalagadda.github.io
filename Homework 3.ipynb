# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
buildings = pd.read_csv("https://uiuc-ischool-dataviz.github.io/is445_AOUAOG_fall2021/week02/data/building_inventory.csv")

# %%
buildings.head()
# Out:
#                        Agency Name  \
# 0  Department of Natural Resources
# 1  Department of Natural Resources
# 2  Department of Natural Resources
# 3  Department of Natural Resources
# 4  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City  Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria     61501  Fulton             17            Cheri Bustos        93
# 1  Astoria     61501  Fulton             17            Cheri Bustos        93
# 2  Astoria     61501  Fulton             17            Cheri Bustos        93
# ...

# %%
buildings.describe()
# Out:
#            Zip code  Congress Dist     Rep Dist  Senate Dist  Year Acquired  \
# count   8862.000000    8862.000000  8862.000000  8862.000000    8862.000000
# mean   61821.076845      13.404085    92.303318    46.408599    1913.267660
# std     1095.203357       4.037936    23.568457    11.781038     337.024796
# min     1235.000000       0.000000     0.000000     0.000000       0.000000
# 25%    61105.000000      12.000000    79.000000    40.000000    1957.000000
# 50%    62023.000000      14.000000    97.000000    49.000000    1975.000000
# 75%    62650.000000      16.000000   110.000000    55.000000    1992.000000
# max    68297.000000      18.000000   119.000000    60.000000    2019.000000
#
#        Year Constructed  Square Footage  Total Floors  Floors Above Grade  \
# count       8862.000000    8.862000e+03   8862.000000         8862.000000
# mean        1906.135184    1.147603e+04      1.636087            1.449334
# ...

# %%
buildings2 = pd.read_csv("https://uiuc-ischool-dataviz.github.io/is445_AOUAOG_fall2021/week02/data/building_inventory.csv",na_values = {'Square Footage': 0,'Year Acquired': 0,'Year Constructed': 0})
# reading the date and filling the empty values with Null

# %%
buildings2.plot(x="Year Acquired", y ="Year Constructed", figsize = (20,4), kind='scatter')
# I really like this plot as the data is alligned with the linear regression
# I am trying to constrct a scatter plot using year  acquired and year constructed

# %%
buildings2.head()
# Out:
#                        Agency Name  \
# 0  Department of Natural Resources
# 1  Department of Natural Resources
# 2  Department of Natural Resources
# 3  Department of Natural Resources
# 4  Department of Natural Resources
#
#                                      Location Name             Address  \
# 0  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 1  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 2  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 3  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
# 4  Anderson Lake Conservation Area - Fulton County  Anderson Lake C.a.
#
#       City  Zip code  County  Congress Dist Congressional Full Name  Rep Dist  \
# 0  Astoria     61501  Fulton             17            Cheri Bustos        93
# 1  Astoria     61501  Fulton             17            Cheri Bustos        93
# 2  Astoria     61501  Fulton             17            Cheri Bustos        93
# ...

# %%
sfs = buildings2.groupby("Bldg Status")["Square Footage"].sum() # total square footage of building status is calculated

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(sfs.index, sfs.values) # using the calculated values to plot
ax.set_yscale('log') # showing larger scale range
ax.set_xlabel('Bldg Status')
ax.set_ylabel('Total Square Footage')
plt.show()
# Firstly i am calculating the sum of square footage of the building based on the building status and storing it in a variable "sfs". Then i am using the index and values from the stored variable to construct a visualization.

# %%
b = buildings2.groupby("Year Acquired")["Square Footage"].median() # claculating the median square footage per acquired year

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax.plot(b.index, b.values) # using the calculated values to plot
ax.set_xlabel("Year acquired") # setting the x label
ax.set_ylabel("Median Sqrft") #setting the y label
plt.show()
# Firstly i am calculating the median of square footage of the building based on the year acquired and storing it in a variable "b". Then i am using the index and values from the stored variable to construct a visualization.

# %%
# the median square footage of the buildign seems to higher between 1800 and 1900
